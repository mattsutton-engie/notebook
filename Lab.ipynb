# %% [markdown]
# ### Lab

# %% [markdown]
# ### test notebook for Best Practices task

# %%
print('Test')
# Out:
# Test

# %% [markdown]
# notebook starts here

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib
import requests

# %%
stocks = ["goog", "aapl", "fb", "amzn"]
public_api_key = 'pk_aa34dd2cc5954efd883a627a69835349'

# %%
stocks_df = None
for stock in stocks:
    data = requests.get(f"https://cloud.iexapis.com/stable/stock/{stock}/chart/3m?token={public_api_key}").json()
    stock_df = pd.DataFrame.from_dict(data)
    stock_df['date'] = pd.to_datetime(stock_df['date'], format="%Y-%m-%d")
    stock_df = stock_df.set_index('date')
    stock_df = stock_df[["close"]]
    stock_df.columns = [ stock ]
    stock_df = stock_df / stock_df[stock][0] # Normalization at t=0
    if stocks_df is None:
        stocks_df = stock_df
    else:
        stocks_df = stocks_df.join(stock_df)

stocks_df.plot(figsize=(12,8))

# %%
stocks2 = 'tsla'

# %%
for stock in stocks:
    data = requests.get(f"https://cloud.iexapis.com/stable/stock/{stock}/chart/3m?token={public_api_key}").json()
    stock_df2 = pd.DataFrame.from_dict(data)
    stock_df2['date'] = pd.to_datetime(stock_df2['date'], format="%Y-%m-%d")
    stock_df2 = stock_df2.set_index('date')
    stock_df2 = stock_df2[["close"]]
    
stock_df2
# Out:
#               close
# date
# 2019-07-17  1992.03
# 2019-07-18  1977.90
# 2019-07-19  1964.52
# 2019-07-22  1985.63
# 2019-07-23  1994.49
# 2019-07-24  2000.81
# 2019-07-25  1973.82
# 2019-07-26  1943.05
# 2019-07-29  1912.45
# 2019-07-30  1898.53
# 2019-07-31  1866.78
# 2019-08-01  1855.32
# 2019-08-02  1823.24
# 2019-08-05  1765.13
# 2019-08-06  1787.83
# 2019-08-07  1793.40
# 2019-08-08  1832.89
# 2019-08-09  1807.58
# 2019-08-12  1784.92
# 2019-08-13  1824.34
# 2019-08-14  1762.96
# 2019-08-15  1776.12
# 2019-08-16  1792.57
# 2019-08-19  1816.12
# 2019-08-20  1801.38
# 2019-08-21  1823.54
# 2019-08-22  1805.60
# 2019-08-23  1749.62
# 2019-08-26  1768.87
# 2019-08-27  1761.83
# ...             ...
# 2019-09-06  1833.51
# 2019-09-09  1831.35
# 2019-09-10  1820.55
# 2019-09-11  1822.99
# 2019-09-12  1843.55
# 2019-09-13  1839.34
# 2019-09-16  1807.84
# 2019-09-17  1822.55
# 2019-09-18  1817.46
# 2019-09-19  1821.50
# 2019-09-20  1794.16
# 2019-09-23  1785.30
# 2019-09-24  1741.61
# 2019-09-25  1768.33
# 2019-09-26  1739.84
# 2019-09-27  1725.45
# 2019-09-30  1735.91
# 2019-10-01  1735.65
# 2019-10-02  1713.23
# 2019-10-03  1724.42
# 2019-10-04  1739.65
# 2019-10-07  1732.66
# 2019-10-08  1705.51
# 2019-10-09  1721.99
# 2019-10-10  1720.26
# 2019-10-11  1731.92
# 2019-10-14  1736.43
# 2019-10-15  1767.38
# 2019-10-16  1777.43
# 2019-10-17  1787.48
#
# [66 rows x 1 columns]

# %%
stock_df2.columns = [ stock ]
stock_df2
# Out:
#                amzn
# date
# 2019-07-17  1992.03
# 2019-07-18  1977.90
# 2019-07-19  1964.52
# 2019-07-22  1985.63
# 2019-07-23  1994.49
# 2019-07-24  2000.81
# 2019-07-25  1973.82
# 2019-07-26  1943.05
# 2019-07-29  1912.45
# 2019-07-30  1898.53
# 2019-07-31  1866.78
# 2019-08-01  1855.32
# 2019-08-02  1823.24
# 2019-08-05  1765.13
# 2019-08-06  1787.83
# 2019-08-07  1793.40
# 2019-08-08  1832.89
# 2019-08-09  1807.58
# 2019-08-12  1784.92
# 2019-08-13  1824.34
# 2019-08-14  1762.96
# 2019-08-15  1776.12
# 2019-08-16  1792.57
# 2019-08-19  1816.12
# 2019-08-20  1801.38
# 2019-08-21  1823.54
# 2019-08-22  1805.60
# 2019-08-23  1749.62
# 2019-08-26  1768.87
# 2019-08-27  1761.83
# ...             ...
# 2019-09-06  1833.51
# 2019-09-09  1831.35
# 2019-09-10  1820.55
# 2019-09-11  1822.99
# 2019-09-12  1843.55
# 2019-09-13  1839.34
# 2019-09-16  1807.84
# 2019-09-17  1822.55
# 2019-09-18  1817.46
# 2019-09-19  1821.50
# 2019-09-20  1794.16
# 2019-09-23  1785.30
# 2019-09-24  1741.61
# 2019-09-25  1768.33
# 2019-09-26  1739.84
# 2019-09-27  1725.45
# 2019-09-30  1735.91
# 2019-10-01  1735.65
# 2019-10-02  1713.23
# 2019-10-03  1724.42
# 2019-10-04  1739.65
# 2019-10-07  1732.66
# 2019-10-08  1705.51
# 2019-10-09  1721.99
# 2019-10-10  1720.26
# 2019-10-11  1731.92
# 2019-10-14  1736.43
# 2019-10-15  1767.38
# 2019-10-16  1777.43
# 2019-10-17  1787.48
#
# [66 rows x 1 columns]

# %% [markdown]
# ### stock testing section over
